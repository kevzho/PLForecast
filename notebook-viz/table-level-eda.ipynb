# %% [markdown]
# # Visualizing Premier League Data (2)

# %% [markdown]
# ##### Source for this data: https://www.bbc.com/sport/football/premier-league/table
# ---
# We're looking at the premier league table to determine **possible** correlation between Goal Difference and Points
#
# *Edit 1-27-26:* This data is no longer scrapable. Will construct table from scratch

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Constructing Premier League Table:

# %%
raw_matches = pd.read_csv(r'../data/E0_2526.csv')

# %% [markdown]
# What we'll do here is take in match-level data and then output the league table (turning 1 row per match into 1 row per team.)

# %% [markdown]
# Every match gives us:
# - Home team
# - Away team
# - Full-time home goals
# - Full-time away goals
#
# What we need is (schema for our dataframe):
# - Team name
# - Matches played by that team
# - Matches won, drawn, and lost by that team
# - Goals fowarded (scored)
# - Goals allowed (conceded)
# - Points (sum up 3 for win, 1 for tie, and 0 for loss)
# - Form (Definitely do last 5 matches)
#
# **Make sure to add up stats for the away team as well. Every match becomes two rows.**
#
# Further ideas:
# - Like njsports.com, they have "strength" rankings where they see how much a team beats another team and compare it with their predictions, and that residual will create "power points", which are averaged and then compared with other teams.

# %%
#testing
for index, row in raw_matches.iterrows():
    print(row['Date'], row['HomeTeam'], row['AwayTeam'], row['FTHG'], row['FTAG'])
# Out:
# 15/08/2025 Liverpool Bournemouth 4 2
# 16/08/2025 Aston Villa Newcastle 0 0
# 16/08/2025 Brighton Fulham 1 1
# 16/08/2025 Sunderland West Ham 3 0
# 16/08/2025 Tottenham Burnley 3 0
# 16/08/2025 Wolves Man City 0 4
# 17/08/2025 Chelsea Crystal Palace 0 0
# 17/08/2025 Nott'm Forest Brentford 3 1
# 17/08/2025 Man United Arsenal 0 1
# 18/08/2025 Leeds Everton 1 0
# 22/08/2025 West Ham Chelsea 1 5
# 23/08/2025 Man City Tottenham 0 2
# 23/08/2025 Bournemouth Wolves 1 0
# 23/08/2025 Brentford Aston Villa 1 0
# 23/08/2025 Burnley Sunderland 2 0
# 23/08/2025 Arsenal Leeds 5 0
# 24/08/2025 Crystal Palace Nott'm Forest 1 1
# 24/08/2025 Everton Brighton 2 0
# 24/08/2025 Fulham Man United 1 1
# 25/08/2025 Newcastle Liverpool 2 3
# 30/08/2025 Chelsea Fulham 2 0
# 30/08/2025 Man United Burnley 3 2
# 30/08/2025 Sunderland Brentford 2 1
# 30/08/2025 Tottenham Bournemouth 0 1
# 30/08/2025 Wolves Everton 2 3
# 30/08/2025 Leeds Newcastle 0 0
# 31/08/2025 Brighton Man City 2 1
# 31/08/2025 Nott'm Forest West Ham 0 3
# 31/08/2025 Liverpool Arsenal 1 0
# 31/08/2025 Aston Villa Crystal Palace 0 3
# 13/09/2025 Arsenal Nott'm Forest 3 0
# 13/09/2025 Bournemouth Brighton 2 1
# 13/09/2025 Crystal Palace Sunderland 0 0
# 13/09/2025 Everton Aston Villa 0 0
# 13/09/2025 Fulham Leeds 1 0
# 13/09/2025 Newcastle Wolves 1 0
# 13/09/2025 West Ham Tottenham 0 3
# 13/09/2025 Brentford Chelsea 2 2
# 14/09/2025 Burnley Liverpool 0 1
# 14/09/2025 Man City Man United 3 0
# 20/09/2025 Liverpool Everton 2 1
# 20/09/2025 Brighton Tottenham 2 2
# 20/09/2025 Burnley Nott'm Forest 1 1
# 20/09/2025 West Ham Crystal Palace 1 2
# 20/09/2025 Wolves Leeds 1 3
# 20/09/2025 Man United Chelsea 2 1
# 20/09/2025 Fulham Brentford 3 1
# 21/09/2025 Bournemouth Newcastle 0 0
# 21/09/2025 Sunderland Aston Villa 1 1
# 21/09/2025 Arsenal Man City 1 1
# 27/09/2025 Brentford Man United 3 1
# 27/09/2025 Chelsea Brighton 1 3
# 27/09/2025 Crystal Palace Liverpool 2 1
# 27/09/2025 Leeds Bournemouth 2 2
# 27/09/2025 Man City Burnley 5 1
# 27/09/2025 Nott'm Forest Sunderland 0 1
# 27/09/2025 Tottenham Wolves 1 1
# 28/09/2025 Aston Villa Fulham 3 1
# 28/09/2025 Newcastle Arsenal 1 2
# 29/09/2025 Everton West Ham 1 1
# 03/10/2025 Bournemouth Fulham 3 1
# 04/10/2025 Leeds Tottenham 1 2
# 04/10/2025 Arsenal West Ham 2 0
# 04/10/2025 Man United Sunderland 2 0
# 04/10/2025 Chelsea Liverpool 2 1
# 05/10/2025 Aston Villa Burnley 2 1
# 05/10/2025 Everton Crystal Palace 2 1
# 05/10/2025 Newcastle Nott'm Forest 2 0
# 05/10/2025 Wolves Brighton 1 1
# 05/10/2025 Brentford Man City 0 1
# 18/10/2025 Nott'm Forest Chelsea 0 3
# 18/10/2025 Brighton Newcastle 2 1
# 18/10/2025 Burnley Leeds 2 0
# 18/10/2025 Crystal Palace Bournemouth 3 3
# 18/10/2025 Man City Everton 2 0
# 18/10/2025 Sunderland Wolves 2 0
# 18/10/2025 Fulham Arsenal 0 1
# 19/10/2025 Tottenham Aston Villa 1 2
# 19/10/2025 Liverpool Man United 1 2
# 20/10/2025 West Ham Brentford 0 2
# 24/10/2025 Leeds West Ham 2 1
# 25/10/2025 Chelsea Sunderland 1 2
# 25/10/2025 Newcastle Fulham 2 1
# 25/10/2025 Man United Brighton 4 2
# 25/10/2025 Brentford Liverpool 3 2
# 26/10/2025 Arsenal Crystal Palace 1 0
# 26/10/2025 Aston Villa Man City 1 0
# 26/10/2025 Bournemouth Nott'm Forest 2 0
# 26/10/2025 Wolves Burnley 2 3
# 26/10/2025 Everton Tottenham 0 3
# 01/11/2025 Brighton Leeds 3 0
# 01/11/2025 Burnley Arsenal 0 2
# 01/11/2025 Crystal Palace Brentford 2 0
# 01/11/2025 Fulham Wolves 3 0
# 01/11/2025 Nott'm Forest Man United 2 2
# 01/11/2025 Tottenham Chelsea 0 1
# 01/11/2025 Liverpool Aston Villa 2 0
# 02/11/2025 West Ham Newcastle 3 1
# 02/11/2025 Man City Bournemouth 3 1
# 03/11/2025 Sunderland Everton 1 1
# 08/11/2025 Tottenham Man United 2 2
# 08/11/2025 Everton Fulham 2 0
# 08/11/2025 West Ham Burnley 3 2
# 08/11/2025 Sunderland Arsenal 2 2
# 08/11/2025 Chelsea Wolves 3 0
# 09/11/2025 Aston Villa Bournemouth 4 0
# 09/11/2025 Brentford Newcastle 3 1
# 09/11/2025 Crystal Palace Brighton 0 0
# 09/11/2025 Nott'm Forest Leeds 3 1
# 09/11/2025 Man City Liverpool 3 0
# 22/11/2025 Burnley Chelsea 0 2
# 22/11/2025 Bournemouth West Ham 2 2
# 22/11/2025 Brighton Brentford 2 1
# 22/11/2025 Fulham Sunderland 1 0
# 22/11/2025 Liverpool Nott'm Forest 0 3
# 22/11/2025 Wolves Crystal Palace 0 2
# 22/11/2025 Newcastle Man City 2 1
# 23/11/2025 Leeds Aston Villa 1 2
# 23/11/2025 Arsenal Tottenham 4 1
# 24/11/2025 Man United Everton 0 1
# 29/11/2025 Brentford Burnley 3 1
# 29/11/2025 Man City Leeds 3 2
# 29/11/2025 Sunderland Bournemouth 3 2
# 29/11/2025 Everton Newcastle 1 4
# 29/11/2025 Tottenham Fulham 1 2
# 30/11/2025 Crystal Palace Man United 1 2
# 30/11/2025 Aston Villa Wolves 1 0
# 30/11/2025 Nott'm Forest Brighton 0 2
# 30/11/2025 West Ham Liverpool 0 2
# 30/11/2025 Chelsea Arsenal 1 1
# 02/12/2025 Bournemouth Everton 0 1
# 02/12/2025 Fulham Man City 4 5
# 02/12/2025 Newcastle Tottenham 2 2
# 03/12/2025 Arsenal Brentford 2 0
# 03/12/2025 Brighton Aston Villa 3 4
# 03/12/2025 Burnley Crystal Palace 0 1
# 03/12/2025 Wolves Nott'm Forest 0 1
# 03/12/2025 Leeds Chelsea 3 1
# 03/12/2025 Liverpool Sunderland 1 1
# 04/12/2025 Man United West Ham 1 1
# 06/12/2025 Aston Villa Arsenal 2 1
# 06/12/2025 Bournemouth Chelsea 0 0
# 06/12/2025 Everton Nott'm Forest 3 0
# 06/12/2025 Man City Sunderland 3 0
# 06/12/2025 Newcastle Burnley 2 1
# 06/12/2025 Tottenham Brentford 2 0
# 06/12/2025 Leeds Liverpool 3 3
# 07/12/2025 Brighton West Ham 1 1
# 07/12/2025 Fulham Crystal Palace 1 2
# 08/12/2025 Wolves Man United 1 4
# 13/12/2025 Chelsea Everton 2 0
# 13/12/2025 Liverpool Brighton 2 0
# 13/12/2025 Burnley Fulham 2 3
# 13/12/2025 Arsenal Wolves 2 1
# 14/12/2025 Crystal Palace Man City 0 3
# 14/12/2025 Nott'm Forest Tottenham 3 0
# 14/12/2025 Sunderland Newcastle 1 0
# 14/12/2025 West Ham Aston Villa 2 3
# 14/12/2025 Brentford Leeds 1 1
# 15/12/2025 Man United Bournemouth 4 4
# 20/12/2025 Newcastle Chelsea 2 2
# 20/12/2025 Bournemouth Burnley 1 1
# 20/12/2025 Brighton Sunderland 0 0
# 20/12/2025 Man City West Ham 3 0
# 20/12/2025 Wolves Brentford 0 2
# 20/12/2025 Tottenham Liverpool 1 2
# 20/12/2025 Everton Arsenal 0 1
# 20/12/2025 Leeds Crystal Palace 4 1
# 21/12/2025 Aston Villa Man United 2 1
# 22/12/2025 Fulham Nott'm Forest 1 0
# 26/12/2025 Man United Newcastle 1 0
# 27/12/2025 Nott'm Forest Man City 1 2
# 27/12/2025 Arsenal Brighton 2 1
# 27/12/2025 Brentford Bournemouth 4 1
# 27/12/2025 Burnley Everton 0 0
# 27/12/2025 Liverpool Wolves 2 1
# 27/12/2025 West Ham Fulham 0 1
# 27/12/2025 Chelsea Aston Villa 1 2
# 28/12/2025 Sunderland Leeds 1 1
# 28/12/2025 Crystal Palace Tottenham 0 1
# 30/12/2025 Burnley Newcastle 1 3
# 30/12/2025 Chelsea Bournemouth 2 2
# 30/12/2025 Nott'm Forest Everton 0 2
# 30/12/2025 West Ham Brighton 2 2
# 30/12/2025 Arsenal Aston Villa 4 1
# 30/12/2025 Man United Wolves 1 1
# 01/01/2026 Crystal Palace Fulham 1 1
# 01/01/2026 Liverpool Leeds 0 0
# 01/01/2026 Brentford Tottenham 0 0
# 01/01/2026 Sunderland Man City 0 0
# 03/01/2026 Aston Villa Nott'm Forest 3 1
# 03/01/2026 Brighton Burnley 2 0
# 03/01/2026 Wolves West Ham 3 0
# 03/01/2026 Bournemouth Arsenal 2 3
# 04/01/2026 Leeds Man United 1 1
# 04/01/2026 Everton Brentford 2 4
# 04/01/2026 Newcastle Crystal Palace 2 0
# 04/01/2026 Tottenham Sunderland 1 1
# 04/01/2026 Fulham Liverpool 2 2
# 04/01/2026 Man City Chelsea 1 1
# 06/01/2026 West Ham Nott'm Forest 1 2
# 07/01/2026 Bournemouth Tottenham 3 2
# 07/01/2026 Brentford Sunderland 3 0
# 07/01/2026 Crystal Palace Aston Villa 0 0
# 07/01/2026 Everton Wolves 1 1
# 07/01/2026 Fulham Chelsea 2 1
# 07/01/2026 Man City Brighton 1 1
# 07/01/2026 Burnley Man United 2 2
# 07/01/2026 Newcastle Leeds 4 3
# 08/01/2026 Arsenal Liverpool 0 0
# 17/01/2026 Man United Man City 2 0
# 17/01/2026 Chelsea Brentford 2 0
# 17/01/2026 Leeds Fulham 1 0
# 17/01/2026 Liverpool Burnley 1 1
# 17/01/2026 Sunderland Crystal Palace 2 1
# 17/01/2026 Tottenham West Ham 1 2
# 17/01/2026 Nott'm Forest Arsenal 0 0
# 18/01/2026 Wolves Newcastle 0 0
# 18/01/2026 Aston Villa Everton 0 1
# 19/01/2026 Brighton Bournemouth 1 1
# 24/01/2026 West Ham Sunderland 3 1
# 24/01/2026 Burnley Tottenham 2 2
# 24/01/2026 Fulham Brighton 2 1
# 24/01/2026 Man City Wolves 2 0
# 24/01/2026 Bournemouth Liverpool 3 2
# 25/01/2026 Brentford Nott'm Forest 0 2
# 25/01/2026 Crystal Palace Chelsea 1 3
# 25/01/2026 Newcastle Aston Villa 0 2
# 25/01/2026 Arsenal Man United 2 3
# 26/01/2026 Everton Leeds 1 1
# 31/01/2026 Brighton Everton 1 1
# 31/01/2026 Leeds Arsenal 0 4
# 31/01/2026 Wolves Bournemouth 0 2
# 31/01/2026 Chelsea West Ham 3 2
# 31/01/2026 Liverpool Newcastle 4 1
# 01/02/2026 Aston Villa Brentford 0 1
# 01/02/2026 Man United Fulham 3 2
# 01/02/2026 Nott'm Forest Crystal Palace 1 1
# 01/02/2026 Tottenham Man City 2 2
# 02/02/2026 Sunderland Burnley 3 0

# %% [markdown]
# ### Constructing table through defaultdict

# %%
#loop through matches
from collections import defaultdict

#initialize raw data storage, schema will be like this:

# "team": [matches played, W, D, L, GF, GA, GD, Points, Last 5 results (tentative)]

raw_df = defaultdict(lambda: [0, 0, 0, 0, 0, 0, 0, 0, []])

for index, row in raw_matches.iterrows():
    #identify home & away team
    home = row['HomeTeam']
    away = row['AwayTeam']

    #get # of goals for both home and away team and also the result of the match
    home_GF = row['FTHG']
    away_GF = row['FTAG']
    result = row['FTR']

    #matches played
    raw_df[home][0] += 1
    raw_df[away][0] += 1

    #GF
    raw_df[home][4] += home_GF
    raw_df[home][5] += away_GF
    raw_df[away][4] += away_GF
    raw_df[away][5] += home_GF

    # Result and points
    if result == 'H':
        #increase win column because home team won
        raw_df[home][1] += 1
        #increase loss column because away team lost
        raw_df[away][3] += 1 
        raw_df[home][7] += 3
        raw_df[home][8].append('W')
        raw_df[home][8] = raw_df[home][8][-5:]  # Keep only last 5 results
        raw_df[away][8].append('L')
        raw_df[away][8] = raw_df[away][8][-5:]  # Keep only last 5 results
    elif result == 'A':
        raw_df[away][1] += 1
        raw_df[home][3] += 1
        raw_df[away][7] += 3
        raw_df[away][8].append('W')
        raw_df[away][8] = raw_df[away][8][-5:]  # Keep only last 5 results
        raw_df[home][8].append('L')
        raw_df[home][8] = raw_df[home][8][-5:]  # Keep only last 5 results
    elif result == 'D':
        raw_df[home][2] += 1
        raw_df[away][2] += 1
        raw_df[home][7] += 1
        raw_df[away][7] += 1
        raw_df[home][8].append('D')
        raw_df[home][8] = raw_df[home][8][-5:]  # Keep only last 5 results
        raw_df[away][8].append('D')
        raw_df[away][8] = raw_df[away][8][-5:]  # Keep only last 5 results

# Goal Difference
for team in raw_df:
    raw_df[team][6] = raw_df[team][4] - raw_df[team][5]

# Build DataFrame
league_table = pd.DataFrame.from_dict(
    raw_df,
    orient='index',
    columns=['MP','W','D','L','GF','GA','GD','Pts','Last5']
)

# Sort like Premier League
league_table = league_table.sort_values(by=['Pts','GD','GF'], ascending=False)

league_table
# Out:
#                 MP   W   D   L  GF  GA  GD  Pts            Last5
# Arsenal         24  16   5   3  46  17  29   53  [W, D, D, L, W]
# Man City        24  14   5   5  49  23  26   47  [D, D, L, W, D]
# Aston Villa     24  14   4   6  35  26   9   46  [W, D, L, W, L]
# Man United      24  11   8   5  44  36   8   41  [D, D, W, W, W]
# Chelsea         24  11   7   6  42  27  15   40  [D, L, W, W, W]
# Liverpool       24  11   6   7  39  33   6   39  [D, D, D, L, W]
# Brentford       24  11   3  10  36  32   4   36  [W, W, L, L, W]
# Sunderland      24   9   9   6  27  26   1   36  [D, L, W, L, W]
# Fulham          24  10   4  10  34  35  -1   34  [D, W, L, W, L]
# Everton         24   9   7   8  26  27  -1   34  [L, D, W, D, D]
# Newcastle       24   9   6   9  33  33   0   33  [W, W, D, L, L]
# Bournemouth     24   8   9   7  40  43  -3   33  [L, W, D, W, W]
# Brighton        24   7  10   7  34  32   2   31  [W, D, D, L, D]
# Tottenham       24   7   8   9  35  33   2   29  [D, L, L, D, D]
# Crystal Palace  24   7   8   9  25  29  -4   29  [L, D, L, L, D]
# Leeds           24   6   8  10  31  42 -11   26  [D, L, W, D, L]
# Nott'm Forest   24   7   5  12  24  35 -11   26  [L, W, D, W, D]
# West Ham        24   5   5  14  29  48 -19   20  [L, L, W, W, L]
# Burnley         24   3   6  15  25  47 -22   15  [L, D, D, D, L]
# Wolves          24   1   5  18  15  45 -30    8  [W, D, D, L, L]

# %%
# need to scrape premier league table data for more analysis
#creating scatter plot of goal diff. vs points

plt.figure(figsize=(8,6))
prem_table_df = league_table.copy()

prem_table_df = prem_table_df.reset_index()
prem_table_df.index = prem_table_df.index + 1

prem_table_df = prem_table_df.rename(columns={'index': 'Team'})

prem_table_df
# Out:
#               Team  MP   W   D   L  GF  GA  GD  Pts            Last5
# 1          Arsenal  24  16   5   3  46  17  29   53  [W, D, D, L, W]
# 2         Man City  24  14   5   5  49  23  26   47  [D, D, L, W, D]
# 3      Aston Villa  24  14   4   6  35  26   9   46  [W, D, L, W, L]
# 4       Man United  24  11   8   5  44  36   8   41  [D, D, W, W, W]
# 5          Chelsea  24  11   7   6  42  27  15   40  [D, L, W, W, W]
# 6        Liverpool  24  11   6   7  39  33   6   39  [D, D, D, L, W]
# 7        Brentford  24  11   3  10  36  32   4   36  [W, W, L, L, W]
# 8       Sunderland  24   9   9   6  27  26   1   36  [D, L, W, L, W]
# 9           Fulham  24  10   4  10  34  35  -1   34  [D, W, L, W, L]
# 10         Everton  24   9   7   8  26  27  -1   34  [L, D, W, D, D]
# 11       Newcastle  24   9   6   9  33  33   0   33  [W, W, D, L, L]
# 12     Bournemouth  24   8   9   7  40  43  -3   33  [L, W, D, W, W]
# 13        Brighton  24   7  10   7  34  32   2   31  [W, D, D, L, D]
# 14       Tottenham  24   7   8   9  35  33   2   29  [D, L, L, D, D]
# 15  Crystal Palace  24   7   8   9  25  29  -4   29  [L, D, L, L, D]
# 16           Leeds  24   6   8  10  31  42 -11   26  [D, L, W, D, L]
# 17   Nott'm Forest  24   7   5  12  24  35 -11   26  [L, W, D, W, D]
# 18        West Ham  24   5   5  14  29  48 -19   20  [L, L, W, W, L]
# 19         Burnley  24   3   6  15  25  47 -22   15  [L, D, D, D, L]
# 20          Wolves  24   1   5  18  15  45 -30    8  [W, D, D, L, L]

# %% [markdown]
# ## Temporal Dynamics Analysis - Team Form (In terms of W, L, and D)

# %%
import matplotlib.pyplot as plt


#taking the top 6 teams for analysis
top_teams = prem_table_df.head(6)['Team'].tolist()

#initializing storage for match stats
match_stats = {team: {'matchweek': [], 'cumulative_pts': [], 'rolling_5_pts': []} for team in top_teams}
cumulative_points = {team: 0 for team in top_teams}
recent_results = {team: [] for team in top_teams}

#looping through raw matches to calculate cumulative points and rolling 5-game average for top teams
for index, row in raw_matches.iterrows():
    matchweek = index // 10 + 1
    
    for team in top_teams:
        is_home = row['HomeTeam'] == team
        is_away = row['AwayTeam'] == team
        
        if is_home or is_away:
            if row['FTR'] == 'H' and is_home:
                pts_earned = 3
            elif row['FTR'] == 'A' and is_away:
                pts_earned = 3
            elif row['FTR'] == 'D':
                pts_earned = 1
            else:
                pts_earned = 0
            
            cumulative_points[team] += pts_earned
            recent_results[team].append(pts_earned)
            
            #recent results only keeps last 5 results
            recent_results[team] = recent_results[team][-5:]
            
            rolling_5_avg = sum(recent_results[team])
            
            match_stats[team]['matchweek'].append(matchweek)
            match_stats[team]['cumulative_pts'].append(cumulative_points[team])
            match_stats[team]['rolling_5_pts'].append(rolling_5_avg)


#plotting
plt.figure(figsize=(12, 6))
for team in top_teams:
    x = np.array(match_stats[team]['matchweek'])
    y = np.array(match_stats[team]['cumulative_pts'])
    plt.plot(x, y, marker='o', label=team, linewidth=2)

plt.xlabel('Matchweek')
plt.ylabel('Cumulative Points')
plt.title('Cumulative Points Over Season - Top 6 Teams')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

#plotting rolling points
plt.figure(figsize=(12, 6))
for team in top_teams[:3]:
    x = np.array(match_stats[team]['matchweek'])
    y = np.array(match_stats[team]['rolling_5_pts'])
    plt.plot(x, y, marker='s', label=f'{team} (5-game avg)', linewidth=2)

plt.xlabel('Matchweek')
plt.ylabel('Points in Last 5 Games')
plt.title('Rolling 5-Game Points Average - Top 3 Teams')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Strength Distributions

# %% [markdown]
# ### 1) Distribution of GD. across teams

# %%
gd = prem_table_df['GD'].values

plt.figure(figsize=(8,5))
plt.hist(gd, bins=10, alpha=0.7, color='salmon', edgecolor='black')
plt.xlabel('Goal Difference')
plt.ylabel('Number of Teams')
plt.title('Distribution of Goal Difference Across Teams')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### 2) Z-Scoring & Percentile each team (according to the mean)

# %%
from scipy.stats import zscore, percentileofscore

#z-score for points and goal difference
prem_table_df['Pts_zscore'] = zscore(prem_table_df['Pts'])
prem_table_df['GD_zscore']  = zscore(prem_table_df['GD'])

#percentile rank for all teams
prem_table_df['Pts_pct'] = prem_table_df['Pts'].apply(lambda x: percentileofscore(prem_table_df['Pts'], x))
prem_table_df['GD_pct']  = prem_table_df['GD'].apply(lambda x: percentileofscore(prem_table_df['GD'], x))

#getting all of the summary columns into another table for easier visualization
summary_cols = ['Team', 'Pts', 'GD', 'Pts_zscore', 'GD_zscore', 'Pts_pct', 'GD_pct']
summary_table = prem_table_df[summary_cols].sort_values(by='Pts', ascending=False).reset_index(drop=True)

#rounding
summary_table['Pts_zscore'] = summary_table['Pts_zscore'].round(2)
summary_table['GD_zscore']  = summary_table['GD_zscore'].round(2)

summary_table['Pts_pct'] = summary_table['Pts_pct'].round(1)
summary_table['GD_pct']  = summary_table['GD_pct'].round(1)

summary_table
# Out:
#               Team  Pts  GD  Pts_zscore  GD_zscore  Pts_pct  GD_pct
# 0          Arsenal   53  29        1.93       2.06    100.0   100.0
# 1         Man City   47  26        1.36       1.85     95.0    95.0
# 2      Aston Villa   46   9        1.26       0.64     90.0    85.0
# 3       Man United   41   8        0.78       0.57     85.0    80.0
# 4          Chelsea   40  15        0.69       1.07     80.0    90.0
# 5        Liverpool   39   6        0.59       0.43     75.0    75.0
# 6        Brentford   36   4        0.31       0.28     67.5    70.0
# 7       Sunderland   36   1        0.31       0.07     67.5    55.0
# 8           Fulham   34  -1        0.11      -0.07     57.5    42.5
# 9          Everton   34  -1        0.11      -0.07     57.5    42.5
# 10     Bournemouth   33  -3        0.02      -0.21     47.5    35.0
# 11       Newcastle   33   0        0.02       0.00     47.5    50.0
# 12        Brighton   31   2       -0.17       0.14     40.0    62.5
# 13       Tottenham   29   2       -0.36       0.14     32.5    62.5
# 14  Crystal Palace   29  -4       -0.36      -0.28     32.5    30.0
# 15           Leeds   26 -11       -0.65      -0.78     22.5    22.5
# 16   Nott'm Forest   26 -11       -0.65      -0.78     22.5    22.5
# 17        West Ham   20 -19       -1.22      -1.35     15.0    15.0
# 18         Burnley   15 -22       -1.70      -1.56     10.0    10.0
# 19          Wolves    8 -30       -2.37      -2.13      5.0     5.0

# %% [markdown]
# We can also convert our Z-scores into qualitative variables describing strength, where:
#
# | Category         | Z-score Range   |
# |-----------------|----------------|
# | **Strong**       | Z ≥ 1          |
# | **Above Average**| 0 ≤ Z < 1      |
# | **Average**      | -1 < Z < 0     |
# | **Weak**         | Z ≤ -1         |

# %%
def strength_category(z):
    if z >= 1:
        return "Strong"
    elif 0 <= z < 1:
        return "Above Average"
    elif -1 < z < 0:
        return "Average"
    else:
        return "Weak"

summary_table['Strength'] = summary_table['Pts_zscore'].apply(strength_category)
#updated summary table with strength category based on points z-score
summary_table
# Out:
#               Team  Pts  GD  Pts_zscore  GD_zscore  Pts_pct  GD_pct  \
# 0          Arsenal   53  29        1.93       2.06    100.0   100.0
# 1         Man City   47  26        1.36       1.85     95.0    95.0
# 2      Aston Villa   46   9        1.26       0.64     90.0    85.0
# 3       Man United   41   8        0.78       0.57     85.0    80.0
# 4          Chelsea   40  15        0.69       1.07     80.0    90.0
# 5        Liverpool   39   6        0.59       0.43     75.0    75.0
# 6        Brentford   36   4        0.31       0.28     67.5    70.0
# 7       Sunderland   36   1        0.31       0.07     67.5    55.0
# 8           Fulham   34  -1        0.11      -0.07     57.5    42.5
# 9          Everton   34  -1        0.11      -0.07     57.5    42.5
# 10     Bournemouth   33  -3        0.02      -0.21     47.5    35.0
# 11       Newcastle   33   0        0.02       0.00     47.5    50.0
# 12        Brighton   31   2       -0.17       0.14     40.0    62.5
# 13       Tottenham   29   2       -0.36       0.14     32.5    62.5
# 14  Crystal Palace   29  -4       -0.36      -0.28     32.5    30.0
# 15           Leeds   26 -11       -0.65      -0.78     22.5    22.5
# 16   Nott'm Forest   26 -11       -0.65      -0.78     22.5    22.5
# 17        West Ham   20 -19       -1.22      -1.35     15.0    15.0
# 18         Burnley   15 -22       -1.70      -1.56     10.0    10.0
# 19          Wolves    8 -30       -2.37      -2.13      5.0     5.0
#
#          Strength
# 0          Strong
# 1          Strong
# 2          Strong
# 3   Above Average
# 4   Above Average
# 5   Above Average
# 6   Above Average
# 7   Above Average
# 8   Above Average
# 9   Above Average
# 10  Above Average
# 11  Above Average
# 12        Average
# 13        Average
# 14        Average
# 15        Average
# 16        Average
# 17           Weak
# 18           Weak
# 19           Weak

# %% [markdown]
# ### Combine tables

# %%
merged_df = pd.merge(prem_table_df, summary_table[['Team', 'Strength']], on='Team')
merged_df
# Out:
#               Team  MP   W   D   L  GF  GA  GD  Pts            Last5  \
# 0          Arsenal  24  16   5   3  46  17  29   53  [W, D, D, L, W]
# 1         Man City  24  14   5   5  49  23  26   47  [D, D, L, W, D]
# 2      Aston Villa  24  14   4   6  35  26   9   46  [W, D, L, W, L]
# 3       Man United  24  11   8   5  44  36   8   41  [D, D, W, W, W]
# 4          Chelsea  24  11   7   6  42  27  15   40  [D, L, W, W, W]
# 5        Liverpool  24  11   6   7  39  33   6   39  [D, D, D, L, W]
# 6        Brentford  24  11   3  10  36  32   4   36  [W, W, L, L, W]
# 7       Sunderland  24   9   9   6  27  26   1   36  [D, L, W, L, W]
# 8           Fulham  24  10   4  10  34  35  -1   34  [D, W, L, W, L]
# 9          Everton  24   9   7   8  26  27  -1   34  [L, D, W, D, D]
# 10       Newcastle  24   9   6   9  33  33   0   33  [W, W, D, L, L]
# 11     Bournemouth  24   8   9   7  40  43  -3   33  [L, W, D, W, W]
# 12        Brighton  24   7  10   7  34  32   2   31  [W, D, D, L, D]
# 13       Tottenham  24   7   8   9  35  33   2   29  [D, L, L, D, D]
# 14  Crystal Palace  24   7   8   9  25  29  -4   29  [L, D, L, L, D]
# 15           Leeds  24   6   8  10  31  42 -11   26  [D, L, W, D, L]
# 16   Nott'm Forest  24   7   5  12  24  35 -11   26  [L, W, D, W, D]
# 17        West Ham  24   5   5  14  29  48 -19   20  [L, L, W, W, L]
# 18         Burnley  24   3   6  15  25  47 -22   15  [L, D, D, D, L]
# 19          Wolves  24   1   5  18  15  45 -30    8  [W, D, D, L, L]
#
#     Pts_zscore  GD_zscore  Pts_pct  GD_pct       Strength
# 0     1.932506   2.060420    100.0   100.0         Strong
# 1     1.358494   1.847273     95.0    95.0         Strong
# 2     1.262825   0.639441     90.0    85.0         Strong
# 3     0.784482   0.568392     85.0    80.0  Above Average
# 4     0.688814   1.065734     80.0    90.0  Above Average
# 5     0.593145   0.426294     75.0    75.0  Above Average
# 6     0.306140   0.284196     67.5    70.0  Above Average
# 7     0.306140   0.071049     67.5    55.0  Above Average
# 8     0.114802  -0.071049     57.5    42.5  Above Average
# 9     0.114802  -0.071049     57.5    42.5  Above Average
# 10    0.019134   0.000000     47.5    50.0  Above Average
# 11    0.019134  -0.213147     47.5    35.0  Above Average
# 12   -0.172203   0.142098     40.0    62.5        Average
# 13   -0.363541   0.142098     32.5    62.5        Average
# 14   -0.363541  -0.284196     32.5    30.0        Average
# 15   -0.650546  -0.781539     22.5    22.5        Average
# 16   -0.650546  -0.781539     22.5    22.5        Average
# 17   -1.224558  -1.349930     15.0    15.0           Weak
# 18   -1.702901  -1.563077     10.0    10.0           Weak
# 19   -2.372581  -2.131469      5.0     5.0           Weak

# %% [markdown]
# ### Export

# %%
# Export league table and summary table to CSV files
merged_df.to_csv(r'../data/summary_table2526.csv', index=False)

print("Summary table exported to ../data/summary_table_2526.csv")
# Out:
# Summary table exported to ../data/summary_table_2526.csv
